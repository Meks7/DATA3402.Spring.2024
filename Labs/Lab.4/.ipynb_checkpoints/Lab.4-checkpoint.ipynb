# %% [markdown]
# # Lab 4- Object Oriented Programming
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
class counter:
    def __init__(self, max_value):
        self.max_value = max_value
        self.value = 0
    
    def increment(self):
        if self.value < self.max_value:
            self.value += 1
        else:
            print("ERROR")

    def reset(self):
        self.value = 0

    def get(self):
        return self.value

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
class counter:
    def __init__(self, max_value):
        self.__max_value = max_value
        self.__value = 0
    
    def increment(self):
        if self.__value < self.max_value:
            self.__value += 1
        else:
            print("ERROR")

    def reset(self):
        self.__value = 0

    def get_max(self):
        return self.__max_value

    def get(self):
        return self.__value == self.__max_value

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class Rectangle:
    def __init__(self, length, width, x=0, y=0):
        self.__length = length
        self.__width = width
        self.__x = x 
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return (self.__length + self.__width) * 2

    #############################
    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
pi = 3.141592653589793238462643383279502884197

class Circle:
    def __init__(self, radius, x=0, y=0):
        self.__radius = radius
        self.__x = x
        self.__y = y 

    def area(self):
        return pi * self.__radius ** 2

    def perimeter(self):
        return 2 * pi * self.__radius

    ############################
    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement your regtangle and circule classes to inherit from the base class and overload the functions accordingly.

# %%
class Shape:
    def area(self):
        raise NotImplementedError("Error")

    def perimeter(self):
        raise NotImplementedError("Error")

    def get_x(self):
        raise NotImplementedError("Error")

    def get_y(self):
        raise NotImplementedError("Error")



pi = math.pi

class Circle (Shape):
    def __init__(self, radius, x=0, y=0):
        self.__radius = radius
        self.__x = x
        self.__y = y 

    def area(self):
        return pi * self.__radius ** 2

    def perimeter(self):
        return 2 * pi * self.__radius

    ############################
    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y



class Rectangle (Shape):
    def __init__(self, length, width, x=0, y=0):
        self.__length = length
        self.__width = width
        self.__x = x 
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return (self.__length + self.__width) * 2

    #############################
    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

# %% [markdown]
# 6. Implement a triangle class analogous to the rectangle and circle in question 5.

# %%
class Triangle:
    def __init__(self, base, height, side, x = 0, y = 0):
        self.__base = base
        self.__height = height
        self.__side = side
        self.__x = x
        self.__y = y

    def area(self):
        return .5 * self.__height * self.__base

    def perimeter(self):
        return 3 * self.__side
#########################################################
    def getx(self):
        return self.__x

    def gety(self):
        return self.__y
        
    def getBase(self):
        return self.__base

    def getHeight(self):
        return self.__height

    def getSide(self):
        return self.__side

# %% [markdown]
# 7. Add a function to the object classes, including the base, that returns a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
import math

class Shape:
    def area(self):
        raise NotImplementedError("Error")

    def perimeter(self):
        raise NotImplementedError("Error")

    def get_x(self):
        raise NotImplementedError("Error")

    def get_y(self):
        raise NotImplementedError("Error")
    
    def get_points(self):
        raise NotImplementedError("Error")

pi = math.pi

class Circle (Shape):
    def __init__(self, radius, x=0, y=0):
        self.__radius = radius
        self.__x = x
        self.__y = y 

    def area(self):
        return pi * self.__radius ** 2

    def perimeter(self):
        return 2 * pi * self.__radius

    def get_points(self):
        points = []
        for i in range(16):
            angle = 2 * pi * i / 16
            points.append((self.__x + math.cos(angle) * self.__radius, 
                           self.__y + math.sin(angle) * self.__radius))
        return points

    ############################
    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y


class Rectangle (Shape):
    def __init__(self, length, width, x=0, y=0):
        self.__length = length
        self.__width = width
        self.__x = x 
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return (self.__length + self.__width) * 2

    def get_points(self):
        points = []
        point = self.perimeter() / 16
        for i in range(16):
            if i < 4:
                points.append((self.__x + i * point (Shape), self.__y))
            elif i < 8:
                points.append((self.__x + self.__length, self.__y + (i - 4) * point))
            elif i < 12: 
                points.append((self.__x + self.__length - (i - 8) * point, self.__y + self.__width))
            else:
                points.append((self.__x, self.__y + self.__width - (i - 12) * point))
        return points

    #############################
    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y


class Triangle (Shape):
    def __init__(self, base, height, side, x = 0, y = 0):
        self.__base = base
        self.__height = height
        self.__side = side
        self.__x = x
        self.__y = y

    def area(self):
        return .5 * self.__height * self.__base

    def perimeter(self):
        return 3 * self.__side

    def get_points(self):
        points = []
        height = (math.sqrt(3)/2) * self.__side
        for i in range(6):
            x = self.__x + (self.__side / 5) * i
            y = self.__y
            points.append((x, y))
        for i in range(1, 6):
            x = self.__x + (self.__side / 2) - (self.__side / 10 * i)
            y = self.__y + height * i / 5
            points.append((x, y))
        for i in range(1, 5):
            x = self.__x + (self.__side / 10 * i)
            y = self.__y + height * i / 5
            points.append((x, y))
        return points
#########################################################
    def getx(self):
        return self.__x

    def gety(self):
        return self.__y
        
    def getBase(self):
        return self.__base

    def getHeight(self):
        return self.__height

    def getSide(self):
        return self.__side

# %% [markdown]
# 8. Add a function to the object classes, including the base, that tests if a given set of $x$ and $y$ coordinates are inside of the object. You'll have to think through how to determine if a set of coordinates are inside an object for each object type.

# %%
import math

class Shape:
    def area(self):
        raise NotImplementedError("Error")

    def perimeter(self):
        raise NotImplementedError("Error")

    def get_x(self):
        raise NotImplementedError("Error")

    def get_y(self):
        raise NotImplementedError("Error")
    
    def get_points(self):
        raise NotImplementedError("Error")
    
    def is_inside(self, x, y):
        raise NotImplementedError("Error")



pi = math.pi

class Circle (Shape):
    def __init__(self, radius, x=0, y=0):
        self.__radius = radius
        self.__x = x
        self.__y = y 

    def area(self):
        return pi * self.__radius ** 2

    def perimeter(self):
        return 2 * pi * self.__radius

    def get_points(self):
        points = []
        for i in range(16):
            angle = 2 * pi * i / 16
            points.append((self.__x + math.cos(angle) * self.__radius, 
                           self.__y + math.sin(angle) * self.__radius))
        return points

    def is_inside(self, x, y):
        distance = math.sqrt((x - self.__x) ** 2 + (y - self.__y) ** 2)
        return distance <= self.__radius


    ############################
    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y



class Rectangle (Shape):
    def __init__(self, length, width, x=0, y=0):
        self.__length = length
        self.__width = width
        self.__x = x 
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return (self.__length + self.__width) * 2

    def get_points(self):
        points = []
        point = self.perimeter() / 16
        for i in range(16):
            if i < 4:
                points.append((self.__x + i * point, self.__y))
            elif i < 8:
                points.append((self.__x + self.__length, self.__y + (i - 4) * point))
            elif i < 12: 
                points.append((self.__x + self.__length - (i - 8) * point, self.__y + self.__width))
            else:
                points.append((self.__x, self.__y + self.__width - (i - 12) * point))
        return points
        
    def is_inside(self, x, y):
        right = self.__x + self.__length
        top = self.__y + self.__width
        return self.__x <= x <= right and self.__y <= y <= top

    #############################
    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y


class Triangle (Shape):
    def __init__(self, base, height, side, x = 0, y = 0):
        self.__base = base
        self.__height = height
        self.__side = side
        self.__x = x
        self.__y = y

    def area(self):
        return .5 * self.__height * self.__base

    def perimeter(self):
        return 3 * self.__side

    def get_points(self):
        points = []
        height = (math.sqrt(3)/2) * self.__side
        for i in range(6):
            x = self.__x + (self.__side / 5) * i
            y = self.__y
            points.append((x, y))
        for i in range(1, 6):
            x = self.__x + (self.__side / 2) - (self.__side / 10 * i)
            y = self.__y + height * i / 5
            points.append((x, y))
        for i in range(1, 5):
            x = self.__x + (self.__side / 10 * i)
            y = self.__y + height * i / 5
            points.append((x, y))
        return points
        
    def is_inside(self, x, y):
    
        A = (self.__x, self.__y)
        B = (self.__x + self.__side, self.__y)
        height = (self.__side * (math.sqrt(3) / 2))
        C = (self.__x + (self.__side / 2), self.__y + height)

        def sign(p1, p2, p3):
            return (p1[0] - p3[0]) * (p2[1] - p3[1]) - (p2[0] - p3[0]) * (p1[1] - p3[1])

        b1 = sign((x, y), A, B) < 0.0
        b2 = sign((x, y), B, C) < 0.0
        b3 = sign((x, y), C, A) < 0.0

        return ((b1 == b2) and (b2 == b3))
#########################################################
    def getx(self):
        return self.__x

    def gety(self):
        return self.__y
        
    def getBase(self):
        return self.__base

    def getHeight(self):
        return self.__height

    def getSide(self):
        return self.__side

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
import math

class Shape:
    def area(self):
        raise NotImplementedError("Error")

    def perimeter(self):
        raise NotImplementedError("Error")

    def get_x(self):
        raise NotImplementedError("Error")

    def get_y(self):
        raise NotImplementedError("Error")
    
    def get_points(self):
        raise NotImplementedError("Error")
    
    def is_inside(self, x, y):
        raise NotImplementedError("Error")

    def appx_radius(self):
        raise NotImplementedError("Error")
    
    def center(self):
        raise NotImplementedError("Error")

    def overlaps_with(self, other_shape):
        x1, y1 = self.center()
        x2, y2 = other_shape.center()
        distance = math.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)
        
        total_radius = self.appx_radius() + other_shape.appx_radius()
        
        return distance < total_radius



pi = math.pi

class Circle (Shape):
    def __init__(self, radius, x=0, y=0):
        self.__radius = radius
        self.__x = x
        self.__y = y 

    def area(self):
        return pi * self.__radius ** 2

    def perimeter(self):
        return 2 * pi * self.__radius

    def get_points(self):
        points = []
        for i in range(16):
            angle = 2 * pi * i / 16
            points.append((self.__x + math.cos(angle) * self.__radius, 
                           self.__y + math.sin(angle) * self.__radius))
        return points

    def is_inside(self, x, y):
        distance = math.sqrt((x - self.__x) ** 2 + (y - self.__y) ** 2)
        return distance <= self.__radius


    ############################
    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y



class Rectangle (Shape):
    def __init__(self, length, width, x=0, y=0):
        self.__length = length
        self.__width = width
        self.__x = x 
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return (self.__length + self.__width) * 2

    def get_points(self):
        points = []
        point = self.perimeter() / 16
        for i in range(16):
            if i < 4:
                points.append((self.__x + i * point, self.__y))
            elif i < 8:
                points.append((self.__x + self.__length, self.__y + (i - 4) * point))
            elif i < 12: 
                points.append((self.__x + self.__length - (i - 8) * point, self.__y + self.__width))
            else:
                points.append((self.__x, self.__y + self.__width - (i - 12) * point))
        return points
        
    def is_inside(self, x, y):
        right = self.__x + self.__length
        top = self.__y + self.__width
        return self.__x <= x <= right and self.__y <= y <= top

    #############################
    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y


class Triangle (Shape):
    def __init__(self, base, height, side, x = 0, y = 0):
        self.__base = base
        self.__height = height
        self.__side = side
        self.__x = x
        self.__y = y

    def area(self):
        return .5 * self.__height * self.__base

    def perimeter(self):
        return 3 * self.__side

    def get_points(self):
        points = []
        height = (math.sqrt(3)/2) * self.__side
        for i in range(6):
            x = self.__x + (self.__side / 5) * i
            y = self.__y
            points.append((x, y))
        for i in range(1, 6):
            x = self.__x + (self.__side / 2) - (self.__side / 10 * i)
            y = self.__y + height * i / 5
            points.append((x, y))
        for i in range(1, 5):
            x = self.__x + (self.__side / 10 * i)
            y = self.__y + height * i / 5
            points.append((x, y))
        return points
        
    def is_inside(self, x, y):
    
        A = (self.__x, self.__y)
        B = (self.__x + self.__side, self.__y)
        height = (self.__side * (math.sqrt(3) / 2))
        C = (self.__x + (self.__side / 2), self.__y + height)

        def sign(p1, p2, p3):
            return (p1[0] - p3[0]) * (p2[1] - p3[1]) - (p2[0] - p3[0]) * (p1[1] - p3[1])

        b1 = sign((x, y), A, B) < 0.0
        b2 = sign((x, y), B, C) < 0.0
        b3 = sign((x, y), C, A) < 0.0

        return ((b1 == b2) and (b2 == b3))
#########################################################
    def getx(self):
        return self.__x

    def gety(self):
        return self.__y
        
    def getBase(self):
        return self.__base

    def getHeight(self):
        return self.__height

    def getSide(self):
        return self.__side

# %% [markdown]
# 10. Copy the `Canvas` class from lecture to in a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %%
import math

class Shape:
    def area(self):
        raise NotImplementedError("Error")

    def perimeter(self):
        raise NotImplementedError("Error")

    def get_x(self):
        raise NotImplementedError("Error")

    def get_y(self):
        raise NotImplementedError("Error")
    
    def get_points(self):
        raise NotImplementedError("Error")
    
    def is_inside(self, x, y):
        raise NotImplementedError("Error")

    def appx_radius(self):
        raise NotImplementedError("Error")
    
    def center(self):
        raise NotImplementedError("Error")

    def overlaps_with(self, other_shape):
        x1, y1 = self.center()
        x2, y2 = other_shape.center()
        distance = math.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)
        
        total_radius = self.appx_radius() + other_shape.appx_radius()
        
        return distance < total_radius



pi = math.pi

class Circle (Shape):
    def __init__(self, radius, x=0, y=0):
        self.__radius = radius
        self.__x = x
        self.__y = y 

    def area(self):
        return pi * self.__radius ** 2

    def perimeter(self):
        return 2 * pi * self.__radius

    def get_points(self):
        points = []
        for i in range(16):
            angle = 2 * pi * i / 16
            points.append((self.__x + math.cos(angle) * self.__radius, 
                           self.__y + math.sin(angle) * self.__radius))
        return points

    def is_inside(self, x, y):
        distance = math.sqrt((x - self.__x) ** 2 + (y - self.__y) ** 2)
        return distance <= self.__radius

    def draw(self, canvas):
        for angle in range(360):
            rad = math.radians(angle)
            x = int(self.__x + self.__radius * math.cos(rad))
            y = int(self.__y + self.__radius * math.sin(rad))
            canvas.set_pixel(y, x, '*')
            
    ############################
    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y



class Rectangle (Shape):
    def __init__(self, length, width, x=0, y=0):
        self.__length = length
        self.__width = width
        self.__x = x 
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return (self.__length + self.__width) * 2

    def get_points(self):
        points = []
        point = self.perimeter() / 16
        for i in range(16):
            if i < 4:
                points.append((self.__x + i * point, self.__y))
            elif i < 8:
                points.append((self.__x + self.__length, self.__y + (i - 4) * point))
            elif i < 12: 
                points.append((self.__x + self.__length - (i - 8) * point, self.__y + self.__width))
            else:
                points.append((self.__x, self.__y + self.__width - (i - 12) * point))
        return points
        
    def is_inside(self, x, y):
        right = self.__x + self.__length
        top = self.__y + self.__width
        return self.__x <= x <= right and self.__y <= y <= top

    def draw(self, canvas):
        for x in range(self.__x, self.__x + self.__length):
            for y in range(self.__y, self.__y + self.__width):
                canvas.set_pixel(y, x, '*')
                
    #############################
    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y


class Triangle (Shape):
    def __init__(self, base, height, side, x = 0, y = 0):
        self.__base = base
        self.__height = height
        self.__side = side
        self.__x = x
        self.__y = y

    def area(self):
        return .5 * self.__height * self.__base

    def perimeter(self):
        return 3 * self.__side

    def get_points(self):
        points = []
        height = (math.sqrt(3)/2) * self.__side
        for i in range(6):
            x = self.__x + (self.__side / 5) * i
            y = self.__y
            points.append((x, y))
        for i in range(1, 6):
            x = self.__x + (self.__side / 2) - (self.__side / 10 * i)
            y = self.__y + height * i / 5
            points.append((x, y))
        for i in range(1, 5):
            x = self.__x + (self.__side / 10 * i)
            y = self.__y + height * i / 5
            points.append((x, y))
        return points
        
    def is_inside(self, x, y):
    
        A = (self.__x, self.__y)
        B = (self.__x + self.__side, self.__y)
        height = (self.__side * (math.sqrt(3) / 2))
        C = (self.__x + (self.__side / 2), self.__y + height)

        def sign(p1, p2, p3):
            return (p1[0] - p3[0]) * (p2[1] - p3[1]) - (p2[0] - p3[0]) * (p1[1] - p3[1])

        b1 = sign((x, y), A, B) < 0.0
        b2 = sign((x, y), B, C) < 0.0
        b3 = sign((x, y), C, A) < 0.0

        return ((b1 == b2) and (b2 == b3))
#########################################################
    def getx(self):
        return self.__x

    def gety(self):
        return self.__y
        
    def getBase(self):
        return self.__base

    def getHeight(self):
        return self.__height

    def getSide(self):
        return self.__side

######################################################################################


class Canvas:
    def __init__(self, width, height):
        self.width = width
        self.height = height
        self.data = [[' '] * width for i in range(height)]

    def set_pixel(self, row, col, char='*'):
        self.data[row][col] = char

    def get_pixel(self, row, col):
        return self.data[row][col]
    
    def clear_canvas(self):
        self.data = [[' '] * self.width for i in range(self.height)]
    
    def v_line(self, x, y, w, **kargs):
        for i in range(x,x+w):
            self.set_pixel(i,y, **kargs)

    def h_line(self, x, y, h, **kargs):
        for i in range(y,y+h):
            self.set_pixel(x,i, **kargs)
            
    def line(self, x1, y1, x2, y2, **kargs):
        slope = (y2-y1) / (x2-x1)
        for y in range(y1,y2):
            x= int(slope * y)
            self.set_pixel(x,y, **kargs)
            
    def display(self):
        print("\n".join(["".join(row) for row in self.data]))


######################

class CompoundShape(Shape):
    def __init__(self):
        super().__init__()
        self.shapes = []

    def add_shape(self, shape):
        self.shapes.append(shape)

    def area(self):
        return sum(shape.area() for shape in self.shapes)

    def perimeter(self):
        return sum(shape.perimeter() for shape in self.shapes)

    def get_points(self):
        points = []
        for shape in self.shapes:
            points.extend(shape.get_points())
        return points

    def is_inside(self, x, y):
        return any(shape.is_inside(x, y) for shape in self.shapes)

    def draw(self, canvas):
        for shape in self.shapes:
            shape.draw(canvas)

    def center(self):
        avg_x = sum(shape.get_x() for shape in self.shapes) / len(self.shapes)
        avg_y = sum(shape.get_y() for shape in self.shapes) / len(self.shapes)
        return avg_x, avg_y

    def appx_radius(self):
        center_x, center_y = self.center()
        return max(math.sqrt((shape.get_x() - center_x) ** 2 + (shape.get_y() - center_y) ** 2) + shape.appx_radius() for shape in self.shapes)


def draw_face(canvas):
    # Head
    head = Circle(10, 15, 15)
    head.draw(canvas)

    # Eyes
    left_eye = Circle(10, 13, 2)
    right_eye = Circle(10, 17, 2)
    left_eye.draw(canvas)
    right_eye.draw(canvas)

    # mouth
    for i in range(10, 21):
        canvas.set_pixel(17, i, '_')

    canvas.display()

canvas = Canvas(30, 30)
draw_face(canvas)
# Out:
#    *   *              *   *
#    *   *              *   *
#    *   *              **  **
#    *   *              *   *
#    *   *              *   *
#    *   *  **********  *   *
#    **  ****        ****  **
#     *  **            **  *
#      * * *          * * *
#      **  **        **  **
#      ****  **    **  ****
#      *  **************  *
#      *       *   *      *
#      *                  *
#      *                  *
#      *                  **
#      *                  *
#      *    ___________   *
#      *                  *
#      **                **
#       *                *
#        *              *
#        **   *   *    **
#         **************
#        ** ********** **
#      **  **    *   **  **
#      *   *          *   *
#     *   *            *   *
#    **  **            **  **
#    *   *              *   *

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %%
import math

class Shape:
    def area(self):
        raise NotImplementedError("Error")

    def perimeter(self):
        raise NotImplementedError("Error")

    def get_x(self):
        raise NotImplementedError("Error")

    def get_y(self):
        raise NotImplementedError("Error")
    
    def get_points(self):
        raise NotImplementedError("Error")
    
    def is_inside(self, x, y):
        raise NotImplementedError("Error")

    def appx_radius(self):
        raise NotImplementedError("Error")
    
    def center(self):
        raise NotImplementedError("Error")

    def overlaps_with(self, other_shape):
        x1, y1 = self.center()
        x2, y2 = other_shape.center()
        distance = math.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)
        
        total_radius = self.appx_radius() + other_shape.appx_radius()
        
        return distance < total_radius



pi = math.pi

class Circle (Shape):
    def __init__(self, radius, x=0, y=0):
        self.__radius = radius
        self.__x = x
        self.__y = y 

    def area(self):
        return pi * self.__radius ** 2

    def perimeter(self):
        return 2 * pi * self.__radius

    def get_points(self):
        points = []
        for i in range(16):
            angle = 2 * pi * i / 16
            points.append((self.__x + math.cos(angle) * self.__radius, 
                           self.__y + math.sin(angle) * self.__radius))
        return points

    def is_inside(self, x, y):
        distance = math.sqrt((x - self.__x) ** 2 + (y - self.__y) ** 2)
        return distance <= self.__radius

    def draw(self, canvas):
        for angle in range(360):
            rad = math.radians(angle)
            x = int(self.__x + self.__radius * math.cos(rad))
            y = int(self.__y + self.__radius * math.sin(rad))
            canvas.set_pixel(y, x, '*')
            
    ############################
    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y



class Rectangle (Shape):
    def __init__(self, length, width, x=0, y=0):
        self.__length = length
        self.__width = width
        self.__x = x 
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return (self.__length + self.__width) * 2

    def get_points(self):
        points = []
        point = self.perimeter() / 16
        for i in range(16):
            if i < 4:
                points.append((self.__x + i * point, self.__y))
            elif i < 8:
                points.append((self.__x + self.__length, self.__y + (i - 4) * point))
            elif i < 12: 
                points.append((self.__x + self.__length - (i - 8) * point, self.__y + self.__width))
            else:
                points.append((self.__x, self.__y + self.__width - (i - 12) * point))
        return points
        
    def is_inside(self, x, y):
        right = self.__x + self.__length
        top = self.__y + self.__width
        return self.__x <= x <= right and self.__y <= y <= top
    
    def draw(self, canvas):
        for x in range(max(0, self.__x), min(self.__x + self.__length, canvas.width)):
            for y in range(max(0, self.__y), min(self.__y + self.__width, canvas.height)):
                canvas.set_pixel(y, x, '*')
    #############################
    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y


class Triangle (Shape):
    def __init__(self, base, height, side, x = 0, y = 0):
        self.__base = base
        self.__height = height
        self.__side = side
        self.__x = x
        self.__y = y

    def area(self):
        return .5 * self.__height * self.__base

    def perimeter(self):
        return 3 * self.__side

    def get_points(self):
        points = []
        height = (math.sqrt(3)/2) * self.__side
        for i in range(6):
            x = self.__x + (self.__side / 5) * i
            y = self.__y
            points.append((x, y))
        for i in range(1, 6):
            x = self.__x + (self.__side / 2) - (self.__side / 10 * i)
            y = self.__y + height * i / 5
            points.append((x, y))
        for i in range(1, 5):
            x = self.__x + (self.__side / 10 * i)
            y = self.__y + height * i / 5
            points.append((x, y))
        return points
        
    def is_inside(self, x, y):
    
        A = (self.__x, self.__y)
        B = (self.__x + self.__side, self.__y)
        height = (self.__side * (math.sqrt(3) / 2))
        C = (self.__x + (self.__side / 2), self.__y + height)

        def sign(p1, p2, p3):
            return (p1[0] - p3[0]) * (p2[1] - p3[1]) - (p2[0] - p3[0]) * (p1[1] - p3[1])

        b1 = sign((x, y), A, B) < 0.0
        b2 = sign((x, y), B, C) < 0.0
        b3 = sign((x, y), C, A) < 0.0

        return ((b1 == b2) and (b2 == b3))
#########################################################
    def getx(self):
        return self.__x

    def gety(self):
        return self.__y
        
    def getBase(self):
        return self.__base

    def getHeight(self):
        return self.__height

    def getSide(self):
        return self.__side

######################################################################################


class Canvas:
    def __init__(self, width, height):
        self.width = width
        self.height = height
        self.data = [[' '] * width for i in range(height)]

    def set_pixel(self, row, col, char='*'):
        self.data[row][col] = char

    def get_pixel(self, row, col):
        return self.data[row][col]
    
    def clear_canvas(self):
        self.data = [[' '] * self.width for i in range(self.height)]
    
    def v_line(self, x, y, w, **kargs):
        for i in range(x,x+w):
            self.set_pixel(i,y, **kargs)

    def h_line(self, x, y, h, **kargs):
        for i in range(y,y+h):
            self.set_pixel(x,i, **kargs)
            
    def line(self, x1, y1, x2, y2, **kargs):
        slope = (y2-y1) / (x2-x1)
        for y in range(y1,y2):
            x= int(slope * y)
            self.set_pixel(x,y, **kargs)
            
    def display(self):
        print("\n".join(["".join(row) for row in self.data]))


######################

class CompoundShape(Shape):
    def __init__(self):
        super().__init__()
        self.shapes = []

    def add_shape(self, shape):
        self.shapes.append(shape)

    def area(self):
        return sum(shape.area() for shape in self.shapes)

    def perimeter(self):
        return sum(shape.perimeter() for shape in self.shapes)

    def get_points(self):
        points = []
        for shape in self.shapes:
            points.extend(shape.get_points())
        return points

    def is_inside(self, x, y):
        return any(shape.is_inside(x, y) for shape in self.shapes)

    def draw(self, canvas):
        for shape in self.shapes:
            shape.draw(canvas)

    def center(self):
        avg_x = sum(shape.get_x() for shape in self.shapes) / len(self.shapes)
        avg_y = sum(shape.get_y() for shape in self.shapes) / len(self.shapes)
        return avg_x, avg_y

    def appx_radius(self):
        center_x, center_y = self.center()
        return max(math.sqrt((shape.get_x() - center_x) ** 2 + (shape.get_y() - center_y) ** 2) + shape.appx_radius() for shape in self.shapes)


def draw_face(canvas):
    # Head
    head = Circle(10, 15, 15)
    head.draw(canvas)

    # Eyes
    left_eye = Circle(10, 13, 2)
    right_eye = Circle(10, 17, 2)
    left_eye.draw(canvas)
    right_eye.draw(canvas)

    # mouth
    for i in range(10, 21):
        canvas.set_pixel(17, i, '_')

    canvas.display()

canvas = Canvas(30, 30)
draw_face(canvas)



class RasterDrawing:
    def __init__(self, width, height):
        self.canvas = Canvas(width, height)
        self.shapes = []

    def add_shape(self, shape):
        self.shapes.append(shape)

    def remove_shape(self, shape):
        if shape in self.shapes:
            self.shapes.remove(shape)

    def paint(self):
        self.canvas.clear_canvas()
        for shape in self.shapes:
            shape.draw(self.canvas)
        self.canvas.display()



######################################################

def draw9(drawing):
    top_circle = Circle(2, 10, 3)
    drawing.add_shape(top_circle)

    straight_line = Rectangle(4, 12, 1, 5)
    drawing.add_shape(straight_line)

    bottom_curve = Rectangle(5, 11, 3, 2)
    drawing.add_shape(bottom_curve)
    
    drawing.paint()

drawing = RasterDrawing(20, 10)

draw9(drawing)
###############
def modify9(drawing):

    drawing.shapes.clear()

    outer_circle_modified = Circle(4, 10, 4)
    drawing.add_shape(outer_circle_modified)

    bottom_part_modified = Rectangle(9, 14, 13, 5)
    drawing.add_shape(bottom_part_modified)

    print("\nModified:")
    drawing.paint()

modify9(drawing)
# Out:
#    *   *              *   *
#    *   *              *   *
#    *   *              **  **
#    *   *              *   *
#    *   *              *   *
#    *   *  **********  *   *
#    **  ****        ****  **
#     *  **            **  *
#      * * *          * * *
#      **  **        **  **
#      ****  **    **  ****
#      *  **************  *
#      *       *   *      *
#      *                  *
#      *                  *
#      *                  **
#      *                  *
#      *    ___________   *
#      *                  *
#      **                **
#       *                *
#        *              *
#        **   *   *    **
#         **************
#        ** ********** **
#      **  **    *   **  **
#      *   *          *   *
#     *   *            *   *
#    **  **            **  **
#    *   *              *   *
#
#         ****
#    ******  *
#    ******  **
#    *********
#  *******  *
#  *******
#  *******
#  *******
#  *******
#
# Modified:
# ...

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
class foo:
    def __init__(self,a,b=None):
        self.a=a
        self.b=b
        
    def __repr__(self):
        return "foo("+repr(self.a)+","+repr(self.b)+")"
    
    def save(self,filename):
        f=open(filename,"w")
        f.write(self.__repr__())
        f.close()
        
   
def foo_loader(filename):
    f=open(filename,"r")
    tmp=eval(f.read())
    f.close()
    return tmp

# %%
# Test
print(repr(foo(1,"hello")))
# Out:
# foo(1,'hello')

# %%
# Create an object and save it
ff=foo(1,"hello")
ff.save("Test.foo")

# %%
# Check contents of the saved file
# !cat Test.foo
# Out:
# foo(1,'hello')

# %%
# Load the object
ff_reloaded=foo_loader("Test.foo")
ff_reloaded
# Out:
# foo(1,'hello')

# %%
import math

class Shape:
    def area(self):
        raise NotImplementedError("Error")

    def perimeter(self):
        raise NotImplementedError("Error")

    def get_x(self):
        raise NotImplementedError("Error")

    def get_y(self):
        raise NotImplementedError("Error")
    
    def get_points(self):
        raise NotImplementedError("Error")
    
    def is_inside(self, x, y):
        raise NotImplementedError("Error")

    def appx_radius(self):
        raise NotImplementedError("Error")
    
    def center(self):
        raise NotImplementedError("Error")

    def overlaps_with(self, other_shape):
        x1, y1 = self.center()
        x2, y2 = other_shape.center()
        distance = math.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)
        
        total_radius = self.appx_radius() + other_shape.appx_radius()
        
        return distance < total_radius



pi = math.pi

class Circle (Shape):
    def __init__(self, radius, x=0, y=0):
        self.__radius = radius
        self.__x = x
        self.__y = y 

    def area(self):
        return pi * self.__radius ** 2

    def perimeter(self):
        return 2 * pi * self.__radius

    def get_points(self):
        points = []
        for i in range(16):
            angle = 2 * pi * i / 16
            points.append((self.__x + math.cos(angle) * self.__radius, 
                           self.__y + math.sin(angle) * self.__radius))
        return points

    def is_inside(self, x, y):
        distance = math.sqrt((x - self.__x) ** 2 + (y - self.__y) ** 2)
        return distance <= self.__radius

    def draw(self, canvas):
        for angle in range(360):
            rad = math.radians(angle)
            x = int(self.__x + self.__radius * math.cos(rad))
            y = int(self.__y + self.__radius * math.sin(rad))
            canvas.set_pixel(y, x, '*')

    def __repr__(self):
        return f"Circle({self.__radius}, {self.__x}, {self.__y})"
            
    ############################
    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y


class Rectangle (Shape):
    def __init__(self, length, width, x=0, y=0):
        self.__length = length
        self.__width = width
        self.__x = x 
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return (self.__length + self.__width) * 2

    def get_points(self):
        points = []
        point = self.perimeter() / 16
        for i in range(16):
            if i < 4:
                points.append((self.__x + i * point, self.__y))
            elif i < 8:
                points.append((self.__x + self.__length, self.__y + (i - 4) * point))
            elif i < 12: 
                points.append((self.__x + self.__length - (i - 8) * point, self.__y + self.__width))
            else:
                points.append((self.__x, self.__y + self.__width - (i - 12) * point))
        return points
        
    def is_inside(self, x, y):
        right = self.__x + self.__length
        top = self.__y + self.__width
        return self.__x <= x <= right and self.__y <= y <= top
    
    def draw(self, canvas):
        for x in range(max(0, self.__x), min(self.__x + self.__length, canvas.width)):
            for y in range(max(0, self.__y), min(self.__y + self.__width, canvas.height)):
                canvas.set_pixel(y, x, '*')
    #############################
    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def __repr__(self):
        return f"Rectangle({self.__length}, {self.__width}, {self.__x}, {self.__y})"


class Triangle (Shape):
    def __init__(self, base, height, side, x = 0, y = 0):
        self.__base = base
        self.__height = height
        self.__side = side
        self.__x = x
        self.__y = y

    def area(self):
        return .5 * self.__height * self.__base

    def perimeter(self):
        return 3 * self.__side

    def get_points(self):
        points = []
        height = (math.sqrt(3)/2) * self.__side
        for i in range(6):
            x = self.__x + (self.__side / 5) * i
            y = self.__y
            points.append((x, y))
        for i in range(1, 6):
            x = self.__x + (self.__side / 2) - (self.__side / 10 * i)
            y = self.__y + height * i / 5
            points.append((x, y))
        for i in range(1, 5):
            x = self.__x + (self.__side / 10 * i)
            y = self.__y + height * i / 5
            points.append((x, y))
        return points
        
    def is_inside(self, x, y):
    
        A = (self.__x, self.__y)
        B = (self.__x + self.__side, self.__y)
        height = (self.__side * (math.sqrt(3) / 2))
        C = (self.__x + (self.__side / 2), self.__y + height)

    def sign(p1, p2, p3):
        return (p1[0] - p3[0]) * (p2[1] - p3[1]) - (p2[0] - p3[0]) * (p1[1] - p3[1])

        b1 = sign((x, y), A, B) < 0.0
        b2 = sign((x, y), B, C) < 0.0
        b3 = sign((x, y), C, A) < 0.0

        return ((b1 == b2) and (b2 == b3))

    def __repr__(self):
        return f"Triangle({self.__base}, {self.__height}, {self.__side}, {self.__x}, {self.__y})"
#########################################################
    def getx(self):
        return self.__x

    def gety(self):
        return self.__y
        
    def getBase(self):
        return self.__base

    def getHeight(self):
        return self.__height

    def getSide(self):
        return self.__side

######################################################################################


class Canvas:
    def __init__(self, width, height):
        self.width = width
        self.height = height
        self.data = [[' '] * width for i in range(height)]

    def set_pixel(self, row, col, char='*'):
        self.data[row][col] = char

    def get_pixel(self, row, col):
        return self.data[row][col]
    
    def clear_canvas(self):
        self.data = [[' '] * self.width for i in range(self.height)]
    
    def v_line(self, x, y, w, **kargs):
        for i in range(x,x+w):
            self.set_pixel(i,y, **kargs)

    def h_line(self, x, y, h, **kargs):
        for i in range(y,y+h):
            self.set_pixel(x,i, **kargs)
            
    def line(self, x1, y1, x2, y2, **kargs):
        slope = (y2-y1) / (x2-x1)
        for y in range(y1,y2):
            x= int(slope * y)
            self.set_pixel(x,y, **kargs)
            
    def display(self):
        print("\n".join(["".join(row) for row in self.data]))


######################

class CompoundShape(Shape):
    def __init__(self):
        super().__init__()
        self.shapes = []

    def add_shape(self, shape):
        self.shapes.append(shape)

    def area(self):
        return sum(shape.area() for shape in self.shapes)

    def perimeter(self):
        return sum(shape.perimeter() for shape in self.shapes)

    def get_points(self):
        points = []
        for shape in self.shapes:
            points.extend(shape.get_points())
        return points

    def is_inside(self, x, y):
        return any(shape.is_inside(x, y) for shape in self.shapes)

    def draw(self, canvas):
        for shape in self.shapes:
            shape.draw(canvas)

    def center(self):
        avg_x = sum(shape.get_x() for shape in self.shapes) / len(self.shapes)
        avg_y = sum(shape.get_y() for shape in self.shapes) / len(self.shapes)
        return avg_x, avg_y

    def appx_radius(self):
        center_x, center_y = self.center()
        return max(math.sqrt((shape.get_x() - center_x) ** 2 + (shape.get_y() - center_y) ** 2) + shape.appx_radius() for shape in self.shapes)


def draw_face(canvas):
    # Head
    head = Circle(10, 15, 15)
    head.draw(canvas)

    # Eyes
    left_eye = Circle(10, 13, 2)
    right_eye = Circle(10, 17, 2)
    left_eye.draw(canvas)
    right_eye.draw(canvas)

    # mouth
    for i in range(10, 21):
        canvas.set_pixel(17, i, '_')

    canvas.display()

canvas = Canvas(30, 30)
draw_face(canvas)



class RasterDrawing:
    def __init__(self, width, height):
        self.canvas = Canvas(width, height)
        self.shapes = []

    def add_shape(self, shape):
        self.shapes.append(shape)

    def remove_shape(self, shape):
        if shape in self.shapes:
            self.shapes.remove(shape)

    def paint(self):
        self.canvas.clear_canvas()
        for shape in self.shapes:
            shape.draw(self.canvas)
        self.canvas.display()
    
    def save(self, filename):
        with open(filename, 'w') as f:
            for shape in self.shapes:
                f.write(repr(shape) + '\n')


######################################################

def draw9(drawing):
    top_circle = Circle(2, 10, 3)
    drawing.add_shape(top_circle)

    straight_line = Rectangle(4, 12, 1, 5)
    drawing.add_shape(straight_line)

    bottom_curve = Rectangle(5, 11, 3, 2)
    drawing.add_shape(bottom_curve)
    
    drawing.paint()

drawing = RasterDrawing(20, 10)

draw9(drawing)
###############
def modify9(drawing):

    drawing.shapes.clear()

    outer_circle_modified = Circle(4, 10, 4)
    drawing.add_shape(outer_circle_modified)

    bottom_part_modified = Rectangle(9, 14, 13, 5)
    drawing.add_shape(bottom_part_modified)

    print("\nModified:")
    drawing.paint()

def load_drawing(filename):
    drawing = RasterDrawing(20, 15)  # Adjust the size if needed based on your requirements
    with open(filename, 'r') as f:
        for line in f:
            shape = eval(line.strip())
            drawing.add_shape(shape)
    return drawing

modify9(drawing)





drawing = RasterDrawing(20, 15)
drawing.add_shape(Circle(3, 10, 5))
drawing.add_shape(Rectangle(5, 15, 2, 4))

drawing.save('drawing_save.txt')

loaded_drawing = load_drawing('drawing_save.txt')

print("Loaded Drawing:")
loaded_drawing.paint()
# Out:
#    *   *              *   *
#    *   *              *   *
#    *   *              **  **
#    *   *              *   *
#    *   *              *   *
#    *   *  **********  *   *
#    **  ****        ****  **
#     *  **            **  *
#      * * *          * * *
#      **  **        **  **
#      ****  **    **  ****
#      *  **************  *
#      *       *   *      *
#      *                  *
#      *                  *
#      *                  **
#      *                  *
#      *    ___________   *
#      *                  *
#      **                **
#       *                *
#        *              *
#        **   *   *    **
#         **************
#        ** ********** **
#      **  **    *   **  **
#      *   *          *   *
#     *   *            *   *
#    **  **            **  **
#    *   *              *   *
#
#         ****
#    ******  *
#    ******  **
#    *********
#  *******  *
#  *******
#  *******
#  *******
#  *******
#
# Modified:
# ...
